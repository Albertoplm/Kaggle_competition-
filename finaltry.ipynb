# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay, mean_squared_error
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.tree import plot_tree
from sklearn.ensemble import GradientBoostingRegressor

# %% [markdown]
# #### Cogiendo las bases

# %%
df = pd.read_csv('data/train.csv')
df.head()
df = df.drop(columns=['id'])

# %%
dff = pd.read_csv('data/features5clean.csv')
dff.head()
# Out:
#    carat  cut  color  clarity  depth  table     x     y     z
# 0   1.01    3      4        5   62.7   58.0  6.36  6.31  3.97
# 1   0.60    2      4        4   64.3   57.0  5.31  5.38  3.43
# 2   1.60    3      3        2   59.4   59.0  7.55  7.60  4.50
# 3   0.30    3      1        5   63.5   58.0  4.27  4.24  2.70
# 4   1.00    3      5        2   62.8   57.0  6.37  6.44  4.02

# %%
dftest = pd.read_csv('data/test5clean.csv')
dftest.head()
# Out:
#    carat  cut  color  clarity  depth  table     x     y     z
# 0   2.01    5      3        3   61.9   57.0  8.14  8.05  5.01
# 1   0.49    2      7        5   57.5   60.0  5.18  5.25  3.00
# 2   1.03    3      5        3   58.6   62.0  6.65  6.60  3.88
# 3   0.90    3      6        3   63.0   56.0  6.11  6.15  3.86
# 4   0.59    5      7        3   62.5   55.0  5.35  5.40  3.36

# %%
dftest1 = pd.read_csv('data/test5clean-Copy1.csv')
dftest1.head()
# Out:
#    carat  cut  color  clarity  depth  table     x     y     z
# 0   2.01    5      3        3   61.9   57.0  8.14  8.05  5.01
# 1   0.49    2      7        5   57.5   60.0  5.18  5.25  3.00
# 2   1.03    3      5        3   58.6   62.0  6.65  6.60  3.88
# 3   0.90    3      6        3   63.0   56.0  6.11  6.15  3.86
# 4   0.59    5      7        3   62.5   55.0  5.35  5.40  3.36

# %% [markdown]
# X = dff
# y = df.price#### Creando modelo

# %%
X = dff
y = df.price

# %%
model = GradientBoostingRegressor(max_depth=9, max_features=6, min_samples_split=11)

# %%
model.fit(X, y)
# Out:
# GradientBoostingRegressor(max_depth=9, max_features=6, min_samples_split=11)

# %%
dftest1["price1"] = model.predict(dftest)

# %%
model1 = GradientBoostingRegressor(max_depth=8, max_features=8, min_samples_split=9, n_estimators=200)

# %%
model1.fit(X, y)
# Out:
# GradientBoostingRegressor(max_depth=8, max_features=8, min_samples_split=9,
#                           n_estimators=200)

# %%
dftest1["price2"] = model1.predict(dftest)

# %%
model2 = GradientBoostingRegressor(max_depth=9, max_features=7, min_samples_split=11)

# %%
model2.fit(X, y)
# Out:
# GradientBoostingRegressor(max_depth=9, max_features=7, min_samples_split=11)

# %%
dftest1["price3"] = model2.predict(dftest)

# %%
model3 = GradientBoostingRegressor(max_depth=8, max_features=8, min_samples_split=5, n_estimators=250)

# %%
model3.fit(X, y)
# Out:
# GradientBoostingRegressor(max_depth=8, max_features=8, min_samples_split=5,
#                           n_estimators=250)

# %%
dftest1["price4"] = model3.predict(dftest)

# %%
model4 = GradientBoostingRegressor(max_depth=9, max_features=6, min_samples_split=7)

# %%
model4.fit(X, y)
# Out:
# GradientBoostingRegressor(max_depth=9, max_features=6, min_samples_split=7)

# %%
dftest1["price5"] = model4.predict(dftest)

# %%
model5 = GradientBoostingRegressor(max_depth=9, max_features=6, min_samples_split=7, n_estimators=300)

# %%
model5.fit(X, y)
# Out:
# GradientBoostingRegressor(max_depth=9, max_features=6, min_samples_split=7,
#                           n_estimators=300)

# %%
dftest1["price6"] = model5.predict(dftest)

# %%
dftest1
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z    price1  \
# 0       2.01    5      3        3   61.9   57.0  8.14  8.05  5.01  9.695353
# 1       0.49    2      7        5   57.5   60.0  5.18  5.25  3.00  7.335150
# 2       1.03    3      5        3   58.6   62.0  6.65  6.60  3.88  8.506346
# 3       0.90    3      6        3   63.0   56.0  6.11  6.15  3.86  8.345417
# 4       0.59    5      7        3   62.5   55.0  5.35  5.40  3.36  7.500815
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...       ...
# 13480   0.41    2      5        1   63.8   57.0  4.72  4.69  3.00  6.389693
# 13481   2.05    3      3        4   63.5   62.0  8.05  7.91  5.07  9.545904
# 13482   2.22    3      2        4   60.5   59.0  8.41  8.37  5.08  9.739885
# 13483   0.51    5      6        2   58.3   62.0  5.20  5.19  3.04  7.072676
# 13484   0.46    3      6        5   61.7   59.0  4.93  4.96  3.05  7.260606
#
#          price2    price3    price4    price5    price6
# ...

# %%
dftest1["price"] = dftest1[["price1","price2","price3","price4","price5", "price6"]].mean(axis=1)

# %%
dftest1
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z    price1  \
# 0       2.01    5      3        3   61.9   57.0  8.14  8.05  5.01  9.695353
# 1       0.49    2      7        5   57.5   60.0  5.18  5.25  3.00  7.335150
# 2       1.03    3      5        3   58.6   62.0  6.65  6.60  3.88  8.506346
# 3       0.90    3      6        3   63.0   56.0  6.11  6.15  3.86  8.345417
# 4       0.59    5      7        3   62.5   55.0  5.35  5.40  3.36  7.500815
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...       ...
# 13480   0.41    2      5        1   63.8   57.0  4.72  4.69  3.00  6.389693
# 13481   2.05    3      3        4   63.5   62.0  8.05  7.91  5.07  9.545904
# 13482   2.22    3      2        4   60.5   59.0  8.41  8.37  5.08  9.739885
# 13483   0.51    5      6        2   58.3   62.0  5.20  5.19  3.04  7.072676
# 13484   0.46    3      6        5   61.7   59.0  4.93  4.96  3.05  7.260606
#
# ...

# %%
attempboost3all = dftest1[["price"]]

# %%
attempboost3all.to_csv('data/attempboost13.csv', index=True)

# %%
df11 = pd.read_csv('data/attempboost13.csv')
df11.head()
# Out:
#    Unnamed: 0     price
# 0           0  9.696195
# 1           1  7.298505
# 2           2  8.505269
# 3           3  8.340860
# 4           4  7.500573

# %%
df11["id"] = df11[["Unnamed: 0"]]

# %%
df11 = df11[["id", "price"]]

# %%
df11.to_csv('data/attempboost13.csv', index=False)

# %%
df11.shape
# Out:
# (13485, 2)
